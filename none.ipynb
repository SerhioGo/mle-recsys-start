# %%
import logging

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
personal = pd.read_parquet("/home/mle-user/mle_projects/mle-recsys-start/final_recommendations_feat.parquet")

# %%
#personal = personal.set_index("user_id")
personal
# Out:
#          user_id   item_id  als_score  cnt_score  cb_score  rank   age  \
# 0        1000003   6148028   1.123475        NaN  0.974376     1   9.0
# 1        1000003   2767052   1.112699        NaN  0.968782     2  10.0
# 2        1000003   7260188   1.129979        NaN  0.962986     3   8.0
# 3        1000003   9361589   1.060634        NaN  0.591806     4   7.0
# 4        1000003  21853621   0.420170        NaN  0.577451     5   3.0
# ...          ...       ...        ...        ...       ...   ...   ...
# 7519395  1430580     18135   0.021450        NaN  0.200332    96  14.0
# 7519396  1430580      1618   0.023068        NaN  0.193956    97   NaN
# 7519397  1430580   2832909   0.016746        NaN  0.188355    98   8.0
# 7519398  1430580  13089710   0.021981        NaN  0.184903    99   6.0
# 7519399  1430580   6487308   0.017960        NaN  0.181514   100   9.0
#
#          average_rating  reading_years  books_read  ...   genre_1  genre_38  \
# ...

# %%
user_id = 9999999
k = 3

# %%
recs = personal.query('user_id == @user_id')
recs
# Out:
# Empty DataFrame
# Columns: [user_id, item_id, als_score, cnt_score, cb_score, rank, age, average_rating, reading_years, books_read, rating_avg, rating_std, books_per_year, genre_25, genre_1, genre_38, genre_18, genre_34, genre_5, genre_16, genre_20, genre_24, genre_33, genre_others]
# Index: []
#
# [0 rows x 24 columns]

# %%
recs = recs["item_id"].to_list()[:k]
recs
# Out:
# [28187230, 27161156, 5]
